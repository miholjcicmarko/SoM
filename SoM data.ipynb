# %%
import pandas as pd

# %%
data = pd.read_csv('Trans_Course_Demos.1 (1).csv')
data
# Out:
#                         PIF ID       ER5              PIFDATE  \
# 0  moontreemidwifery@gmail.com  21040716  10/29/2021 19:46:08
# 1     allie.evans@hsc.utah.edu  21040716  11/03/2021 19:15:49
#
#           Date created            City State  Registration Zip  \
# 0  10/29/2021 19:44:07             NaN   NaN               NaN
# 1  11/03/2021 19:12:02  Salt Lake City    UT               NaN
#
#    Years in HIV Care Ryan White Funded  PIF3  ...  PIF14  PIF15  PIF16  PIF17  \
# 0                NaN                No   NaN  ...   12.0    0.0    0.0    0.0
# 1                NaN                No   NaN  ...    NaN    NaN    NaN    NaN
#
#    PIF18  PIF19  PIF20  PIF21  PIF22  PIF23
# 0    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN
#
# [2 rows x 65 columns]

# %%
data.columns
# Out:
# Index(['PIF ID', 'ER5', 'PIFDATE', 'Date created', 'City', 'State',
#        'Registration Zip', 'Years in HIV Care', 'Ryan White Funded', 'PIF3',
#        'PIF4', 'PIF5', 'PIF6 01', 'PIF6 02', 'PIF6 03', 'PIF6 04', 'PIF6 05',
#        'PIF7', 'PIF8 01', 'PIF8 02', 'PIF8 03', 'PIF9', 'PIF10 01', 'PIF10 02',
#        'PIF10 03', 'PIF10 04', 'PIF10 05', 'PIF10 06', 'PIF10 07', 'PIF10 08',
#        'PIF10 09', 'PIF10 10', 'PIF10 11', 'PIF10 12', 'PIF10 13', 'PIF3OTH',
#        'PIF3OTH2', 'PIF4OTH', 'PIF Created DATE', 'Local Partner Site',
#        'Eval complete', 'Attended', 'PIF10 14', 'PIF10 15', 'PIF10 16',
#        'PIF10 17', 'PIF10 18', 'PIF10 19', 'PIF10 20', 'PIF10 21', 'PIF10 22',
#        'PIF10 23', 'PIF11', 'PIF12', 'PIF13', 'PIF14', 'PIF15', 'PIF16',
#        'PIF17', 'PIF18', 'PIF19', 'PIF20', 'PIF21', 'PIF22', 'PIF23'],
#       dtype='object')

# %%
data = pd.DataFrame()
data["PIFID"] = ["moontreemidwifery@gmail.com", "allie.evans@hsc.utah.edu", "bailey.jones@hsc.utah.edu"]
data["ER5"] = [21040716, 21040718, 21040719]
data["PIFDATE"] = ["10/29/2021 19:46:08", "11/03/2021 19:15:49", "11/05/2021 19:15:49"]
data['City'] = ["Sandy", "Salt Lake City", "Logan"]
data["State"] = ["UT", "UT", "UT"]
data["Registration Zip"] = [84109, 84109, 84109]
data["Years in HIV Care"] = [1,2, 3]
data["PIF3"] = [17,18, 1]
data["PIF4"] = [4,14, 1]
data["PIF5"] = [0,0, 1]
data["PIF601"] = [0,0,0]
data["PIF602"] = [0,0,0]
data["PIF603"] = [1,1,0]
data["PIF604"] = [0,0,0]
data["PIF605"] = [0,0,0]
data["PIF7"] = [3,9,1]
data["PIF8"] = [8,23, 1]
data["PIF901"] = [84109, 84109, 84109]
data["PIF902"] = [float("NaN"), float("NaN"), float("NaN")]
data["PIF903"] = [float("NaN"), float("NaN"), float("NaN")]
data["PIF10"] = [0,0, 0]
data["PIF11"] = [0,0,0]
data["PIF3_Specify_OtherAllied"] = ["Surgical Tech",float("NaN"), float("NaN")]
data["PIF3_Specify_OtherNonClinical"] = [float("NaN"),"Front Desk Receptionist", float("NaN")]
data["PIF4_Specify"] = [float("NaN"),"Continuing Education Student", float("NaN")]
data["PIF12"] = [0,0, 1]
data["PIF13"] = [0,0, 9]
data["PIF14"] = [0,0, 1]
data["PIF15"] = [0,1, 0]
data["PIF16"] = [float("NaN"),1, float("NaN")]
data["PIF17"] = [float("NaN"),3, float("NaN")]
data["PIF18"] = [float("NaN"),44, float("NaN")]
data["PIF19"] = [float("NaN"),3, float("NaN")]
data["PIF20"] = [float("NaN"),3, float("NaN")]
data["PIF21"] = [float("NaN"),3, float("NaN")]
data["PIF22"] = [float("NaN"),3, float("NaN")]
data["PIF23"] = [float("NaN"),3, float("NaN")]
data
# Out:
#                          PIFID       ER5              PIFDATE            City  \
# 0  moontreemidwifery@gmail.com  21040716  10/29/2021 19:46:08           Sandy
# 1     allie.evans@hsc.utah.edu  21040718  11/03/2021 19:15:49  Salt Lake City
# 2    bailey.jones@hsc.utah.edu  21040719  11/05/2021 19:15:49           Logan
#
#   State  Registration Zip  Years in HIV Care  PIF3  PIF4  PIF5  ...  PIF14  \
# 0    UT             84109                  1    17     4     0  ...      0
# 1    UT             84109                  2    18    14     0  ...      0
# 2    UT             84109                  3     1     1     1  ...      1
#
#    PIF15  PIF16  PIF17  PIF18  PIF19  PIF20  PIF21  PIF22  PIF23
# 0      0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      1    1.0    3.0   44.0    3.0    3.0    3.0    3.0    3.0
# 2      0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [3 rows x 37 columns]

# %%
data.dtypes
# Out:
# PIFID                             object
# ER5                                int64
# PIFDATE                           object
# City                              object
# State                             object
# Registration Zip                   int64
# Years in HIV Care                  int64
# PIF3                               int64
# PIF4                               int64
# PIF5                               int64
# PIF601                             int64
# PIF602                             int64
# PIF603                             int64
# PIF604                             int64
# PIF605                             int64
# PIF7                               int64
# PIF8                               int64
# PIF901                             int64
# PIF902                           float64
# PIF903                           float64
# PIF10                              int64
# PIF11                              int64
# PIF3_Specify_OtherAllied          object
# PIF3_Specify_OtherNonClinical     object
# PIF4_Specify                      object
# PIF12                              int64
# PIF13                              int64
# PIF14                              int64
# PIF15                              int64
# PIF16                            float64
# PIF17                            float64
# PIF18                            float64
# PIF19                            float64
# PIF20                            float64
# PIF21                            float64
# PIF22                            float64
# PIF23                            float64
# dtype: object

# %%
pif_id = data["PIFID"]
data = data.drop("PIFID", axis = 1)
data["PIFID"] = pif_id
data
# Out:
#         ER5              PIFDATE            City State  Registration Zip  \
# 0  21040716  10/29/2021 19:46:08           Sandy    UT             84109
# 1  21040718  11/03/2021 19:15:49  Salt Lake City    UT             84109
# 2  21040719  11/05/2021 19:15:49           Logan    UT             84109
#
#    Years in HIV Care  PIF3  PIF4  PIF5  PIF601  ...  PIF15  PIF16  PIF17  \
# 0                  1    17     4     0       0  ...      0    NaN    NaN
# 1                  2    18    14     0       0  ...      1    1.0    3.0
# 2                  3     1     1     1       0  ...      0    NaN    NaN
#
#    PIF18  PIF19  PIF20  PIF21  PIF22  PIF23                        PIFID
# 0    NaN    NaN    NaN    NaN    NaN    NaN  moontreemidwifery@gmail.com
# 1   44.0    3.0    3.0    3.0    3.0    3.0     allie.evans@hsc.utah.edu
# 2    NaN    NaN    NaN    NaN    NaN    NaN    bailey.jones@hsc.utah.edu
#
# [3 rows x 37 columns]

# %%
for i in range(len(data.columns)):
    if data.dtypes[i] == "object" and i != 0:
        data = data.rename(columns={data.columns[i]: data.columns[i]+"Categ"})
    elif i == 0:
        data = data.rename(columns={data.columns[i]: "ID"})
data
# Out:
#          ID         PIFDATECateg       CityCateg StateCateg  Registration Zip  \
# 0  21040716  10/29/2021 19:46:08           Sandy         UT             84109
# 1  21040718  11/03/2021 19:15:49  Salt Lake City         UT             84109
# 2  21040719  11/05/2021 19:15:49           Logan         UT             84109
#
#    Years in HIV Care  PIF3  PIF4  PIF5  PIF601  ...  PIF15  PIF16  PIF17  \
# 0                  1    17     4     0       0  ...      0    NaN    NaN
# 1                  2    18    14     0       0  ...      1    1.0    3.0
# 2                  3     1     1     1       0  ...      0    NaN    NaN
#
#    PIF18  PIF19  PIF20  PIF21  PIF22  PIF23                   PIFIDCateg
# 0    NaN    NaN    NaN    NaN    NaN    NaN  moontreemidwifery@gmail.com
# 1   44.0    3.0    3.0    3.0    3.0    3.0     allie.evans@hsc.utah.edu
# 2    NaN    NaN    NaN    NaN    NaN    NaN    bailey.jones@hsc.utah.edu
#
# [3 rows x 37 columns]

# %%
for i in range(len(data)):
    data["PIFDATECateg"][i] = data["PIFDATECateg"][i][:8]
data
# Out:
# <ipython-input-16-9835e488416a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["PIFDATECateg"][i] = data["PIFDATECateg"][i][:8]
#          ID PIFDATECateg       CityCateg StateCateg  Registration Zip  \
# 0  21040716     10/29/20           Sandy         UT             84109
# 1  21040718     11/03/20  Salt Lake City         UT             84109
# 2  21040719     11/05/20           Logan         UT             84109
#
#    Years in HIV Care  PIF3  PIF4  PIF5  PIF601  ...  PIF15  PIF16  PIF17  \
# 0                  1    17     4     0       0  ...      0    NaN    NaN
# 1                  2    18    14     0       0  ...      1    1.0    3.0
# 2                  3     1     1     1       0  ...      0    NaN    NaN
#
#    PIF18  PIF19  PIF20  PIF21  PIF22  PIF23                   PIFIDCateg
# 0    NaN    NaN    NaN    NaN    NaN    NaN  moontreemidwifery@gmail.com
# 1   44.0    3.0    3.0    3.0    3.0    3.0     allie.evans@hsc.utah.edu
# 2    NaN    NaN    NaN    NaN    NaN    NaN    bailey.jones@hsc.utah.edu
#
# [3 rows x 37 columns]

# %%
data.dtypes
# Out:
# ID                                      int64
# PIFDATECateg                           object
# CityCateg                              object
# StateCateg                             object
# Registration Zip                        int64
# Years in HIV Care                       int64
# PIF3                                    int64
# PIF4                                    int64
# PIF5                                    int64
# PIF601                                  int64
# PIF602                                  int64
# PIF603                                  int64
# PIF604                                  int64
# PIF605                                  int64
# PIF7                                    int64
# PIF8                                    int64
# PIF901                                  int64
# PIF902                                float64
# PIF903                                float64
# PIF10                                   int64
# PIF11                                   int64
# PIF3_Specify_OtherAlliedCateg          object
# PIF3_Specify_OtherNonClinicalCateg     object
# PIF4_SpecifyCateg                      object
# PIF12                                   int64
# PIF13                                   int64
# PIF14                                   int64
# PIF15                                   int64
# PIF16                                 float64
# PIF17                                 float64
# PIF18                                 float64
# PIF19                                 float64
# PIF20                                 float64
# PIF21                                 float64
# PIF22                                 float64
# PIF23                                 float64
# PIFIDCateg                             object
# dtype: object

# %%
data.to_csv("FakeData2.csv", index = False)

# %%
for i in range(len(data.iloc[0])):
    print(data.columns[i])
    print(data.iloc[0][i])

# %%
data = pd.read_csv('data/demo.csv')

# %%
data["Age"] = [25,23,30,19,25,37,43,32]

# %%
data

# %%
data.to_csv("FakeSoMData.csv", index = False)
